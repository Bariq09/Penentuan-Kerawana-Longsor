# %% [markdown]
# # -----------LAPORAN TUGAS AKHIR SEMESTER KECERDASAN BUATAN-----------
# ![LAP-2.png](attachment:LAP-2.png)
# ### ------------------------------------------------------------NAMA : BARIQ ADHI NUGRAHA----------------------------------------------------
# ### ------------------------------------------------------------------NIM : 09011281924052-------------------------------------------------------------
# ### -----------------------------------------------------------------------KELAS : SK5B------------------------------------------------------------------
# ### -----------------------------------------------------------JURUSAN : SISTEM KOMPUTER-----------------------------------------------------
#
#
# ## -----------------------------------------------FAKULTAS ILMU KOMPUTER-----------------------------------------
# ## --------------------------------------------------UNIVERSITAS SRIWIJAYA-------------------------------------------
# ## -------------------------------------------------------------2020/2021-------------------------------------------------------

# %% [markdown]
# # ------------------------------------PENGERTIAN LONGSOR --------------------------------------
# Longsor adalah sebuah fenomena bencana alam atau peristiwa geologi yang terjadi karena pergerakan massa batuan atau tanah dengan berbagi tipe dan jenis seperti jatuhnya bebatuan atau gumpalan besar tanah.
#
# VARIABEL PENYEBAB TERJADINYA LONGSOR
# Gejala umum tanah longsor ditandai dengan munculnya retakan-retakan dilereng yang sejajar dengan arah tebing, biasanya terjadi setelah hujan, munculnya mata air baru secara tiba-tiba dan tebing rapuh serta kerikil mulai berjatuhan. (Nandi; 2007). Faktor penyebabnya antara lain :
#
# 1.	Lereng Terjal
# Lereng atau tebing yang terjal akan memperbesar gaya pendorong. Lereng yang terjal terbentuk karena pengikisan air sungai, mata air, air laut dan angin
#
# 2.	Ketinggian
# Semakin tinggi maka semakin besar potensi jatuhnya tanah.
#
# 3.	Curah Hujan
# Musim kering yang panjang akan menyebabkan terjadinya penguapan air dipermukaan tanah dalam jumlah besar. Ketika hujan, air akan menyusup kebagian yang retak sehingga tanah dengan cepat mengambang kembali dan dapat menyebabkan terjadinya longsor .
#
#
# 4.	Jenis Tanah
# Jenis tanah yang kurang padat adalah tanah lempung atau tanah liat dengan ketebalan lebih dari 2,5 m dari sudut lereng lebih dari 220. Tanah jenis ini memiliki potensi terjadinya tanah longsor.
# 5.	Penggunaan Lahan
# Tanah longsor sering terjadi di daerah tata lahan persawahan, perladangan dan adanya genangan air dilereng yang terjal.

# %% [markdown]
# # -------------------------------------------LOGIKA FUZZY----------------------------------------------
# Konsep tentang Logika Fuzzy diperkenalkan oleh Prof. Lotfi Astor Zadeh pada tahun 1962. Logika Fuzzy adalah metodologi sistem control pemecahan masalah, yang cocok untuk diimplementasikan pada sistem, mulai dari sistem yang sederhana, sistem kecil, embedded system, jaringan PC, multi-channel atau workstation berbasis akuisisi data, dan sistem kontrol. Bila dibandingkan dengan logika konvensional, kelebihan logika fuzzy adalah kemampuannya dalam proses penalaran secara bahasa sehingga dalam perancangannya tidak memerlukan persamaan matematik yang rumit. Beberapa alasan yang dapat diutarakan mengapa kita menggunakan logika fuzzy diantaranya adalah mudah dimengerti, memiliki toleransi terhadap data-data yang tidak tepat, mampu memodelkan fungsi- fungsi nonlinier yang sangat kompleks, dapat membangun dan mengaplikasikan pengalaman-pengalaman para pakar secara langsung tanpa harus melalui proses pelatihan, dapat berkerjasama dengan teknik- teknik kendali secara konvensional, dan didasarkan pada bahasa alami, (T. Sutojo, et al., 2010).
#
# Suatu sistem berbasis aturan fuzzy logic terdiri dari tiga komponen utama yaitu Fuzzification, Inference dan Defuzzification (Suyanto, 2008, p. 28), terlihat seperti gambar berikut ini :

# %% [markdown]
# ![image.png](attachment:image.png)
# Gambar 1.0 Sistem berbasis aturan Fuzzy Logic

# %% [markdown]
# # -------------------------Sistem Tahap Berbasi Aturan Logika Fuzzy-------------------------
# ## 1. Fuzzyfication
# Fuzzifikasi merupakan proses pemetaan nilai-nilai input (crisp input) yang berasal dari sistem yang dikontrol ke dalam himpunan fuzzy menurut fungsi keanggotaannya. Himpunan fuzzy tersebut merupakan fuzzy input yang akan diolah secara fuzzy pada proses berikutnya.
# ## 2. Inference
# First order logic
# mereprentasikan fakta dan aturan di dunia nyata dengan menggunakan objek, predikat(relasi), dan conectives serta quantifier sehingga beberapa fakta sederhana dapat direprentasikan ke dalam suatu kalimat logika, dan semua relasi bersifat tetap. Menurut (Suyanto, 2008, p. 29) untuk membedakan First-Order Logic secara sintaks aturan Fuzzy Logic dituliskan seperti di bawah ini:
# IF antecendent THEN consequent
# Pada tahap inference diproses hubungan antara nilai-nilai input (crisp input) dan nilai-nilai output (crisp output) yang dikehendaki dengan aturan-aturan (rules). Aturan ini nantinya yang akan menentukan respon sistem terhadap berbagai kondisi setting point dan gangguan yang terjadi pada sistem.
# ## 3. Defuzzyfication
# Pada tahap ini dilakukan pemetaan bagi nilai-nilai fuzzy output yang dihasilkan pada tahap inference ke nilai-nilai output kuantitatif yang sesuai dengan sistem yang diharapkan.
#
# Menurut (Suyanto, 2008, p. 28) ada lima
# metode untuk melakukan proses defuzzyfication, diantaranya yaitu :
#
# a. Centroid method
#
# Metode Centroid method dinamakan juga sebagai Center of Area (CoA) atau
# Center of Gravity (CoG). Jika y* bernilai crisp pada metode ini akan dihitung
# menggunakan rumus:

# %% [markdown]
# ![11.png](attachment:11.png)

# %% [markdown]
# Dan Jika y* bernilai diskrit maka dapat diganti dengan persamaan berikut:

# %% [markdown]
# ![11A.png](attachment:11A.png)

# %% [markdown]
# Dimana y adalah nilai crisp dan adalah derajat keanggotaan y.
#
# b. Height method
#
# Metode ini memilih nilai crisp yang memiliki derajat keanggotaan
# maksimun. Metode ini hanya bisa dipakai oleh fungsi keanggotaan yang
# memiliki derajat keanggotaan 1 pada nilai crisp tunggal dan 0 pada nilai crisp
# yang lain. Fungsi seperti ini disebut fungsi singleton.
#
# c. First (or Last ) of maxima
#
# Pada metode First (or Last ) of maxima fungsi keanggotaan output memiliki
# lebih dari satu nilai maksimun. Sehingga nilai crisp yang digunakan adalah
# salah satu dari nilai yang dihasilkan dari nilai maksimun pertama ataupun
# yang terakhir.
#
# d. Mean-max method
#
# Mean-max method merupakan bentuk umun dari height method dimana
# terdapat lebih dari satu nilai crisp yang memiliki derajat keanggotaan
# maksimun.
# Didefinisikan y* sebagai titik tengah antara nilai crisp yang paling kecil dan
# nilai crisp yang paling besar. Berikut fungsi Mean-max method:
# ![q.png](attachment:q.png)

# %% [markdown]
# Dimana M merupakan nilai crisp paling besar dan m adalah nilai crisp input
# paling kecil.
#
# e. Weighted Average
#
# Weighted Average merupakan suatu metode dengan menggunakan
# pembobotan pada derajat keanggotaan. Di definisikan sebagai berikut:
#
# Dimana y merupakan nilai crisp dan adalah derajat keanggotaan dari
# nilai crisp y. Secara garis besar proses Fuzzy logic digambarkan gambar 2.
# berikut ini :
# ![w.png](attachment:w.png)

# %% [markdown]
# # Hasil Proyek:
# ### RANCANGAN PENELITIAN
# Jenis penelitian yang digunakan dalam penelitian ini adalah model eksperimen, penelitian eksperimen ini bertujuan untuk membuat sistem cerdas berbasis logika fuzzy untuk memudahkan dalam mengetahui daerah rawan longsor dengan memasukkan beberapa jenis Variabel yang diambil dari Peta Kabupaten Aceh Tengah Tahun 2012. Pengumpulan data menggunakan cara literatur yaitu pengumpulan data dilakukan melalui pengamatan langsung yang berkaitan dengan objek penelitian dan pengamatan ini dilakukan dengan cara melihat lima buah jenis Peta Kabupaten Aceh Tengah, kelima jenis Peta itu yaitu Peta Jenis Tanah, Peta Curah Hujan, Peta Kemiringan Tanah, Peta Ketinggian Tanah, dan Peta Tutupan Lahan. Seperti terlihat pada gambar berikut ini :

# %% [markdown]
# ![1a.png](attachment:1a.png)

# %% [markdown]
# ![2a.png](attachment:2a.png)

# %% [markdown]
# ![3a.png](attachment:3a.png)

# %% [markdown]
# ![4a.png](attachment:4a.png)

# %% [markdown]
# ![5a.png](attachment:5a.png)

# %% [markdown]
# peta tersebut diambil titik koordinat yang sama sebagai sampel yaitu pemilihan sejumlah item tertentu dari seluruh item yang ada dengan tujuan mempelajari sebagian item tersebut untuk mewakili seluruh itemnya. Cara pengambilan sampel yang dilakukan adalah pengambilan sampel secara acak dimana pengambilan sampel dilakukan sebanyak 33 titik. Setelah titik koordinat dan keadaan masing-masing variabel diketahui, maka didapat nilai setiap variabel tersebut seperti yang terlihat pada tabel 1 berikut ini :

# %% [markdown]
# ## Data Variabel yang digunakan
# Setelah titik koordinat dan keadaan masing-masing variabel diketahui, maka didapat nilai setiap variabel tersebut seperti yang terlihat pada tabel 1 berikut ini :
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)
# Sumber : Peta Kabupaten Aceh Tengah 2012

# %% [markdown]
# ## Proses fuzzifikasi
# Secara lebih detail dapat diuraikan sebagai berikut:
# 1.	Kemiringan Tanah
#
# Tabel 2. Nilai linguistik Kelerengan
# ![3.png](attachment:3.png)
# Ekpresi untuk fungsi keanggotaan fuzzy.

# %% [markdown]
# ![4.png](attachment:4.png)
# Dimana x merupakan anggota himpunan kemiringan tanah.

# %% [markdown]
# 2.	Ketinggian Tanah
#
# Tabel 3. Nilai linguistik Ketinggian
# ![5.png](attachment:5.png)

# %% [markdown]
# Ekpresi untuk fungsi keanggotaan fuzzy :
# ![6.png](attachment:6.png)
# Dimana y merupakan anggota himpunan ketinggian tanah.

# %% [markdown]
# 3.	Curah Hujan
#
# Tabel 4. Nilai linguistik Curah Hujan
# ![7.png](attachment:7.png)

# %% [markdown]
# Ekpresi untuk fungsi keanggotaan fuzzy :
# ![8.png](attachment:8.png)
# Dimana z merupakan anggota himpunan Curah Hujan.

# %% [markdown]
# 4.	Jenis Tanah
#
# Tabel 5. Nilai linguistik Jenis Tanah
# ![9.png](attachment:9.png)

# %% [markdown]
# Ekpresi untuk fungsi keanggotaan fuzzy :
# ![10.png](attachment:10.png)
# Dimana k merupakan anggota himpunan Jenis Tanah

# %% [markdown]
# 5.	Penggunaan Lahan
#
# Tabel 6. Nilai linguistik Penggunaan Lahan
# ![17.png](attachment:17.png)

# %% [markdown]
# Ekpresi untuk fungsi keanggotaan fuzzy :
# ![18.png](attachment:18.png)
# Dimana l merupakan anggota himpunan Penggunaan Lahan

# %% [markdown]
# 6.	Tingkat Kerawanan Bahaya Longsor
#
# Tabel 7. Nilai linguistik tingkat kerentanan bahaya longsor
# ![a.png](attachment:a.png)

# %% [markdown]
# Ekpresi untuk fungsi keanggotaan fuzzy :
# ![b.png](attachment:b.png)
# dimana m merupakan anggota himpunan Tingkat Kerawanan Bahaya Longsor

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl

# %% [markdown]
# # Input Variabel:
# ## Fuzzifikasi Kemiringan tanah
# ### input:
# ### 1.Kemiringan tanah
#
# Datar < 10
#
# Landai 10 - 20
#
# Agak Curam 20 -30
#
# Curam 30 -40
#
# Terjal > 40

# %%
land_slide = ctrl.Antecedent(np.arange(0,50,1),'land_slide')
slide_x = np.arange(0,50,1)

# %%
land_slide["Datar"] = fuzz.trapmf(land_slide.universe,[0,0,5,10])
land_slide["Landai"] = fuzz.trimf(land_slide.universe,[5,10,20])
land_slide["Agak Curam"] = fuzz.trimf(land_slide.universe,[15,20,30])
land_slide["Curam"] = fuzz.trimf(land_slide.universe,[25,30,40])
land_slide["Terjal"] = fuzz.trapmf(land_slide.universe,[35,40,50,50])

# %% [markdown]
# ## Plotting Kemiringan Tanah

# %% [markdown]
# ### Kemiringan Tanah Datar

# %%
#Kemiringan Tanah Datar
print('#Kemiringan Tanah Datar')
land_datar = fuzz.trapmf(slide_x,[0,0,5,10])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(slide_x, land_datar, 'blue')
ax0.set_title('Datar')
# Out:
# #Kemiringan Tanah Datar
# Text(0.5, 1.0, 'Datar')

# %% [markdown]
# ### Kemiringan Tanah Landai

# %%
#Kemiringan Tanah Landai
print('#Kemiringan Tanah Landai')
land_landai = fuzz.trimf(slide_x,[5,10,20])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(slide_x, land_landai, 'orange')
ax0.set_title('Landai')
# Out:
# #Kemiringan Tanah Landai
# Text(0.5, 1.0, 'Landai')

# %% [markdown]
# ### Kemiringan Tanah Agak Curam

# %%
print('#Kemiringan Tanah Agak Curam')
land_agak_curam = fuzz.trimf(slide_x,[15,20,30])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(slide_x, land_agak_curam, 'red')
ax0.set_title('Agak Curam')
# Out:
# #Kemiringan Tanah Agak Curam
# Text(0.5, 1.0, 'Agak Curam')

# %% [markdown]
# ### Kemiringan Tanah Curam

# %%
#Kemiringan Tanah Curam
print('#Kemiringan Tanah Curam')
land_curam = fuzz.trimf(slide_x,[25,30,40])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(slide_x, land_curam, 'green')
ax0.set_title('Curam')
# Out:
# #Kemiringan Tanah Curam
# Text(0.5, 1.0, 'Curam')

# %% [markdown]
# ### Kemiringan Tanah Terjal

# %%
#Kemiringan Tanah Terjal
print('#Kemiringan Tanah Terjal')
land_terjal = fuzz.trapmf(slide_x,[35,40,50,50])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(slide_x, land_terjal, 'black')
ax0.set_title('Terjal')
# Out:
# #Kemiringan Tanah Terjal
# Text(0.5, 1.0, 'Terjal')

# %% [markdown]
# ### Output:

# %%
land_slide.view()
# Out:
# C:\Users\Bariq09\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Fuzzifikasi Ketinggian Tanah
# ### input:
# ### 2. Ketinggian Tanah
#
# Rendah < 10
#
# Tinggi 10 - 20
#
# Sangat tinggi > 20

# %%
land_high = ctrl.Antecedent(np.arange(0,30,1),'land_high')
high_x = np.arange(0,30,1)

# %%
land_high["Rendah"] = fuzz.trimf(land_high.universe,[0,7,10])
land_high["Tinggi"] = fuzz.trimf(land_high.universe,[5,10,20])
land_high["Sangat Tinggi"] = fuzz.trapmf(land_high.universe,[15,20,30,30])

# %% [markdown]
# ## Plotting Ketinggian Tanah

# %% [markdown]
# ### Ketinggian Tanah Rendah

# %%
#Ketinggian Tanah Rendah
print('#Ketinggian Tanah Rendah')
land_rendah = fuzz.trimf(high_x,[0,7,10])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(high_x, land_rendah, 'black')
ax0.set_title('Rendah')
# Out:
# #Ketinggian Tanah Rendah
# Text(0.5, 1.0, 'Rendah')

# %% [markdown]
# ### Ketinggian Tanah Tinggi

# %%
#Ketinggian Tanah Tinggi
print("Ketinggian Tanah Tinggi")
land_tinggi = fuzz.trimf(high_x,[5,10,20])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(high_x, land_tinggi, 'red')
ax0.set_title('Tinggi')
# Out:
# Ketinggian Tanah Tinggi
# Text(0.5, 1.0, 'Tinggi')

# %% [markdown]
# ### Ketinggian Tanah Sangat Tinggi

# %%
#Ketinggian Tanah Sangat Tinggi
print('Ketinggian Tanah Sangat Tinggi')
land_very_high = fuzz.trapmf(high_x,[15,20,30,30])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(high_x, land_very_high, 'blue')
ax0.set_title('Sangat Tinggi')
# Out:
# Ketinggian Tanah Sangat Tinggi
# Text(0.5, 1.0, 'Sangat Tinggi')

# %% [markdown]
# ### Output:

# %%
land_high.view()
# Out:
# C:\Users\Bariq09\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Fuzzifikasi Curah Hujan
# ### input:
# ### 3.Curah Hujan
#
# Datar < 10
#
# Landai 10 - 20
#
# Agak Curam 20 -30
#
# Curam 30 -40
#
# Terjal > 40

# %%
rain_rate = ctrl.Antecedent(np.arange(0,50,1),'rain_rate')
rain_x = np.arange(0,50,1)

# %%
rain_rate["Sangat Rendah"] = fuzz.trapmf(rain_rate.universe,[0,0,5,10])
rain_rate["Rendah"] = fuzz.trimf(rain_rate.universe,[5,10,20])
rain_rate["Sedang"] = fuzz.trimf(rain_rate.universe,[15,20,30])
rain_rate["Tinggi"] = fuzz.trimf(rain_rate.universe,[25,30,40])
rain_rate["Sangat Tinggi"] = fuzz.trapmf(rain_rate.universe,[35,40,50,50])

# %% [markdown]
# ## Plotting Curah Hujan
#
# ### Curah Hujan Sangat Rendah

# %%
#Curah Hujan Rendah
print('Curah Hujan Sangat Rendah')
rain_very_low = fuzz.trapmf(rain_x,[0,0,5,10])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(rain_x, rain_very_low, 'blue')
ax0.set_title('Sangat Rendah')
# Out:
# Curah Hujan Sangat Rendah
# Text(0.5, 1.0, 'Sangat Rendah')

# %% [markdown]
# ### Curah Hujan Rendah

# %%
#Curah Hujan
print('Curah Hujan Rendah')
rain_low = fuzz.trimf(rain_x,[5,10,20])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(rain_x, rain_low, 'orange')
ax0.set_title('Rendah')
# Out:
# Curah Hujan Rendah
# Text(0.5, 1.0, 'Rendah')

# %% [markdown]
# ### Curah Hujan Sedang

# %%
#Curah Hujan Sedang
print('Curah Hujan Sedang')
rain_mid = fuzz.trimf(rain_x,[15,20,30])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(rain_x, rain_mid, 'red')
ax0.set_title('Sedang')
# Out:
# Curah Hujan Sedang
# Text(0.5, 1.0, 'Sedang')

# %% [markdown]
# ### Curah Hujan Tinggi

# %%
#Curah Hujan Tinggi
print('Curah Hujan Tinggi')
rain_high = fuzz.trimf(rain_x,[25,30,40])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(rain_x, rain_high, 'green')
ax0.set_title('Tinggi')
# Out:
# Curah Hujan Tinggi
# Text(0.5, 1.0, 'Tinggi')

# %% [markdown]
# ### Curah Hujan Sangat Tinggi

# %%
#Curah Hujan Sangat Tinggi
print('Curah Hujan Sangat Tinggi')
rain_very_high = fuzz.trapmf(rain_x,[35,40,50,50])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(rain_x, rain_very_high, 'black')
ax0.set_title('Sangat Tinggi')
# Out:
# Curah Hujan Sangat Tinggi
# Text(0.5, 1.0, 'Sangat Tinggi')

# %% [markdown]
# ### Output:

# %%
rain_rate.view()
# Out:
# C:\Users\Bariq09\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Fuzzifikasi Tipe Tanah
# ### input:
# ### 4.Tipe Tanah
#
# Tidak Peka > 10
#
# Kurang Peka 10 - 20
#
# Agak Peka 20 -30
#
# Peka < 30

# %%
land_type = ctrl.Antecedent(np.arange(0,40,1),'land_type')
type_x = np.arange(0,40,1)

# %%
land_type["Tidak Peka"] = fuzz.trapmf(land_type.universe,[0,0,5,10])
land_type["Kurang Peka"] = fuzz.trimf(land_type.universe,[5,10,20])
land_type["Agak Peka"] = fuzz.trimf(land_type.universe,[10,20,30])
land_type["Sangat Peka"] = fuzz.trapmf(land_type.universe,[25,30,40,40])

# %% [markdown]
# ## Plotting Tipe Tanah
# ### Tipe Tanah Tidak Peka

# %%
#Tipe Tanah Tidak Peka
print('#Tipe Tanah Tidak Peka')
land_not_sensitive = fuzz.trapmf(type_x,[0,0,5,10])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(type_x, land_not_sensitive, 'red')
ax0.set_title('Tidak Peka')
# Out:
# #Tipe Tanah Tidak Peka
# Text(0.5, 1.0, 'Tidak Peka')

# %% [markdown]
# ### Tipe Tanah Kurang Peka

# %%
#Tipe Tanah Kurang Peka
print('#Tipe Tanah Kurang Peka')
land_less_sensitive = fuzz.trimf(type_x,[5,10,20])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(type_x, land_less_sensitive, 'yellow')
ax0.set_title('Kurang Peka')
# Out:
# #Tipe Tanah Kurang Peka
# Text(0.5, 1.0, 'Kurang Peka')

# %% [markdown]
# ### Tipe Tanah Agak Peka

# %%
#Tipe Tanah Agak Peka
print('#Tipe Tanah Agak Peka')
land_semi_sensitive = fuzz.trimf(type_x,[10,20,30])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(type_x, land_semi_sensitive, 'blue')
ax0.set_title('Agak Peka')
# Out:
# #Tipe Tanah Agak Peka
# Text(0.5, 1.0, 'Agak Peka')

# %% [markdown]
# ### Tipe Tanah Peka

# %%
#Tipe Sangat Tanah Peka
print('#Tipe Tanah Sangat Peka')
land_sensitive = fuzz.trapmf(type_x,[25,30,40,40])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(type_x, land_sensitive, 'green')
ax0.set_title('Sangat Peka')
# Out:
# #Tipe Tanah Sangat Peka
# Text(0.5, 1.0, 'Sangat Peka')

# %% [markdown]
# ### Output:

# %%
land_type.view()
# Out:
# C:\Users\Bariq09\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Fuzzifikasi Penggunaan Lahan
# ### input:
# ### 5.Penggunaan Lahan
#
# Rendah > 10
#
# Sedang 10 - 20
#
# Tinggi 20 -30
#
# Sangat Tinggi < 30

# %%
land_use = ctrl.Antecedent(np.arange(0,40,1),'land_use')
use_x = np.arange(0,40,1)

# %%
land_use["Rendah"] = fuzz.trapmf(land_use.universe,[0,0,5,10])
land_use["Sedang"] = fuzz.trimf(land_use.universe,[5,10,20])
land_use["Tinggi"] = fuzz.trimf(land_use.universe,[15,20,30])
land_use["Sangat Tinggi"] = fuzz.trapmf(land_use.universe,[25,30,40,40])

# %% [markdown]
# ## Plotting Penggunaan Lahan
# ### Penggunaan Lahan Rendah

# %%
#Penggunaan Lahan Rendah
print('#Penggunaan Lahan Rendah')
land_low_use = fuzz.trapmf(use_x,[0,0,5,10])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(use_x, land_low_use, 'yellow')
ax0.set_title('Rendah')
# Out:
# #Penggunaan Lahan Rendah
# Text(0.5, 1.0, 'Rendah')

# %% [markdown]
# ### Penggunaan Lahan Sedang

# %%
#Penggunaan Lahan Sedang
print('#Penggunaan Lahan Sedang')
land_mid_use = fuzz.trimf(use_x,[5,10,20])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(use_x, land_mid_use, 'blue')
ax0.set_title('Sedang')
# Out:
# #Penggunaan Lahan Sedang
# Text(0.5, 1.0, 'Sedang')

# %% [markdown]
# ### Penggunaan Lahan Tinggi

# %%
#Penggunaan Lahan Tinggi
print('#Penggunaan Lahan Tinggi')
land_high_use = fuzz.trimf(use_x,[15,20,30])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(use_x, land_high_use, 'red')
ax0.set_title('Tinggi')
# Out:
# #Penggunaan Lahan Tinggi
# Text(0.5, 1.0, 'Tinggi')

# %% [markdown]
# ### Penggunaan Lahan Sangat Tinggi

# %%
#Penggunaan Lahan Sangat Tinggi
print('#Penggunaan Lahan Sangat Tinggi')
land_very_high_use = fuzz.trapmf(use_x,[25,30,40,40])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(use_x, land_very_high_use, 'green')
ax0.set_title('Sangat Tinggi')
# Out:
# #Penggunaan Lahan Sangat Tinggi
# Text(0.5, 1.0, 'Sangat Tinggi')

# %% [markdown]
# ### Output:

# %%
land_use.view()
# Out:
# C:\Users\Bariq09\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # Output Variabel:
# ## Fuzzifikasi Tingkat Kerawanan Longsor
# ### 5.Tingkat Kerawanan Longsor
#
# Tidak Rawan > 3.40
#
# Kerawanan Rendah 3,40 - 4,50
#
# Kerawanan Sedang 4,50 - 5,40
#
# Kerawanan Tinggi 5,40 - 7,00
#
# Sangat Rawan < 7,00

# %%
avalanche_danger = ctrl.Consequent(np.arange(0,10,1),'avalanche_danger')
danger_x = np.arange(0,10,1)

# %%
avalanche_danger["Tidak Rawan"] = fuzz.trapmf(avalanche_danger.universe,[0,0,3.40,3.40])
avalanche_danger["Kerawanan Rendah"] = fuzz.trimf(avalanche_danger.universe,[3.40,3.98,4.50])
avalanche_danger["Kerawanan Sedang"] = fuzz.trimf(avalanche_danger.universe,[4.50,4.98,5.40])
avalanche_danger["Kerawanan Tinggi"] = fuzz.trimf(avalanche_danger.universe,[5.40,5.98,7.00])
avalanche_danger["Sangat Rawan"] = fuzz.trapmf(avalanche_danger.universe,[7.00,7.00,10,10])

# %% [markdown]
# ## Plotting Tingkat Rawan Longsor
# ### Tidak Rawan Longsor

# %%
#Kerawanan Longsor Sedang
print('#Tidak Rawan Longsor')
avalanche_sedang = fuzz.trapmf(danger_x,[0,0,3.40,3.40])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(danger_x, avalanche_sedang, 'blue')
ax0.set_title('Tidak Rawan')
# Out:
# #Tidak Rawan Longsor
# Text(0.5, 1.0, 'Tidak Rawan')

# %% [markdown]
# ### Kerawanan Longsor Rendah

# %%
#Kerawanan Longsor Sedang
print('#Kerawanan Longsor Rendah')
avalanche_sedang = fuzz.trimf(danger_x,[3.40,3.98,4.50])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(danger_x, avalanche_sedang, 'blue')
ax0.set_title('Kerawanan Rendah')
# Out:
# #Kerawanan Longsor Rendah
# Text(0.5, 1.0, 'Kerawanan Rendah')

# %% [markdown]
# ### Kerawanan Longsor Sedang

# %%
#Kerawanan Longsor Sedang
print('#Kerawanan Longsor Sedang')
avalanche_sedang = fuzz.trimf(danger_x,[4.50,4.98,5.40])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(danger_x, avalanche_sedang, 'green')
ax0.set_title('Kerawanan Sedang')
# Out:
# #Kerawanan Longsor Sedang
# Text(0.5, 1.0, 'Kerawanan Sedang')

# %% [markdown]
# ### Kerawanan Longsor Tinggi

# %%
#Kerawanan Longsor Tinggi
print('#Kerawanan Longsor Tinggi')
avalanche_tinggi = fuzz.trimf(danger_x,[5.40,5.98,7.00])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(danger_x, avalanche_tinggi, 'yellow')
ax0.set_title('Kerawanan Tinggi')
# Out:
# #Kerawanan Longsor Tinggi
# Text(0.5, 1.0, 'Kerawanan Tinggi')

# %% [markdown]
# ### Sangat Rawan

# %%
#Sangat Rawan
print('#Sangat Rawan')
very_high_avalanche= fuzz.trapmf(danger_x,[7.00,7.00,10,10])
fig, (ax0) = plt.subplots(nrows=1, figsize=(6,6))
ax0.plot(danger_x, very_high_avalanche, 'orange')
ax0.set_title('Sangat Rawan')
# Out:
# #Sangat Rawan
# Text(0.5, 1.0, 'Sangat Rawan')

# %% [markdown]
# ### Output:

# %%
avalanche_danger.view()
# Out:
# C:\Users\Bariq09\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Proses Inferensi
# Dengan menggunakan logika fuzzy maka didapatkan tingkat
# kerawanan longsor sebagaimana yang terdapat pada tabel 8 berikut ini :
#
# ![111.png](attachment:111.png)

# %%
rule1 = ctrl.Rule(rain_rate['Sedang'] & land_high['Rendah'] & land_slide['Agak Curam'] & land_use['Sedang'] & land_type['Sangat Peka'], avalanche_danger['Kerawanan Sedang'])
rule2 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Sedang'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule3 = ctrl.Rule(rain_rate['Sedang'] & land_high['Rendah'] & land_slide['Agak Curam'] & land_use['Tinggi'] & land_type['Sangat Peka'], avalanche_danger['Kerawanan Sedang'])
rule4 = ctrl.Rule(rain_rate['Sedang'] & land_high['Rendah'] & land_slide['Agak Curam'] & land_use['Sedang'] & land_type['Sangat Peka'], avalanche_danger['Kerawanan Sedang'])
rule5 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Sedang'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule6 = ctrl.Rule(rain_rate['Sedang'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Sedang'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule7 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Rendah'] & land_slide['Agak Curam'] & land_use['Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule8 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Rendah'] & land_slide['Curam'] & land_use['Sedang'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule9 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Tinggi'])
rule10 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Tinggi'] & land_slide['Landai'] & land_use['Sedang'] & land_type['Agak Peka'], avalanche_danger['Kerawanan Sedang'])
rule11 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Tinggi'] & land_type['Agak Peka'], avalanche_danger['Kerawanan Tinggi'])
rule12 = ctrl.Rule(rain_rate['Sedang'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule13 = ctrl.Rule(rain_rate['Sedang'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule14 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Tinggi'] & land_slide['Agak Curam'] & land_use['Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule15 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Tinggi'] & land_slide['Agak Curam'] & land_use['Sedang'] & land_type['Sangat Peka'], avalanche_danger['Kerawanan Tinggi'])
rule16 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Tinggi'] & land_slide['Agak Curam'] & land_use['Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule17 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Tinggi'])
rule18 = ctrl.Rule(rain_rate['Sedang'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule19 = ctrl.Rule(rain_rate['Sedang'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Sedang'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule20 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Tinggi'])
rule21 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Sedang'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule22 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Sedang'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule23 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Sedang'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule24 = ctrl.Rule(rain_rate['Sedang'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Sangat Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Tinggi'])
rule25 = ctrl.Rule(rain_rate['Sedang'] & land_high['Tinggi'] & land_slide['Landai'] & land_use['Tinggi'] & land_type['Agak Peka'], avalanche_danger['Kerawanan Sedang'])
rule26 = ctrl.Rule(rain_rate['Sedang'] & land_high['Tinggi'] & land_slide['Landai'] & land_use['Sangat Tinggi'] & land_type['Agak Peka'], avalanche_danger['Kerawanan Sedang'])
rule27 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Sangat Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Tinggi'])
rule28 = ctrl.Rule(rain_rate['Sedang'] & land_high['Rendah'] & land_slide['Curam'] & land_use['Sangat Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule29 = ctrl.Rule(rain_rate['Sedang'] & land_high['Tinggi'] & land_slide['Landai'] & land_use['Tinggi'] & land_type['Agak Peka'], avalanche_danger['Kerawanan Sedang'])
rule30 = ctrl.Rule(rain_rate['Sedang'] & land_high['Tinggi'] & land_slide['Curam'] & land_use['Tinggi'] & land_type['Agak Peka'], avalanche_danger['Kerawanan Tinggi'])
rule31 = ctrl.Rule(rain_rate['Sedang'] & land_high['Tinggi'] & land_slide['Landai'] & land_use['Sangat Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule32 = ctrl.Rule(rain_rate['Sedang'] & land_high['Rendah'] & land_slide['Landai'] & land_use['Sangat Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Sedang'])
rule33 = ctrl.Rule(rain_rate['Tinggi'] & land_high['Rendah'] & land_slide['Curam'] & land_use['Sangat Tinggi'] & land_type['Kurang Peka'], avalanche_danger['Kerawanan Tinggi'])

# %%
stop_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25,rule26,rule27,rule28,rule29,rule30,rule31,rule32,rule33])

# %% [markdown]
# ## Proses Defuzzifikasi
# Proses untuk menghitung derajat keanggotaan dapat diilustrasikan
# dengan contoh data pertama yang mempunyai curah hujan = 30,
# ketinggian = 7, kemiringan = 30, bukaan lahan = 38, jenis tanah = 18
# sebagai berikut :

# %%
stop = ctrl.ControlSystemSimulation(stop_ctrl)

# %%
stop.input['rain_rate'] = 30
stop.input['land_high'] = 7
stop.input['land_slide'] = 30
stop.input['land_type'] = 18
stop.input['land_use'] = 38

# %% [markdown]
# Input
# curah hujan = 30,
# ketinggian = 7, kemiringan = 30, bukaan lahan = 38, jenis tanah = 18

# %%
stop.compute()

# %%
print(stop.output['avalanche_danger'])
# Out:
# 6.0

# %%
rain_rate.view(sim=stop)
# Out:
# C:\Users\Bariq09\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
land_high.view(sim=stop)
# Out:
# C:\Users\Bariq09\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
land_slide.view(sim=stop)
# Out:
# C:\Users\Bariq09\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
land_type.view(sim=stop)
# Out:
# C:\Users\Bariq09\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
land_use.view(sim=stop)
# Out:
# C:\Users\Bariq09\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
avalanche_danger.view(sim=stop)
# Out:
# C:\Users\Bariq09\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Perhitungan Manual

# %% [markdown]
# ![22.png](attachment:22.png)

# %% [markdown]
# ![IMG_20211106_201807-2.jpg](attachment:IMG_20211106_201807-2.jpg)

# %% [markdown]
# Selanjutnya untuk masing-masing data dapat dilihat pada tabel 9 di bawah
# ini :
# ![AI.png](attachment:AI.png)

# %% [markdown]
# Setelah derajat keanggotaan masing-masing dihitung, proses
# selanjutnya adalah menghitung defuzzifikasi dengan metode centroid
# method/center of grafity dengan rumus sebagai berikut ini :
# ![AI2.png](attachment:AI2.png)
# Dimana y adalah nilai crisp dan (y) adalah derajat keanggotaan dari y.

# %% [markdown]
# Sebagai contoh, proses defuzzifikasi untuk data pertama mempunyai
# curah hujan = 30, ketinggian = 7, kemiringan = 30, bukaan lahan = 38,
# jenis tanah = 18 dihasilkan nilai sebagai berikut :
# ![AI3-2.png](attachment:AI3-2.png)

# %% [markdown]
# Dilihat berdasarkan range pada tingkat kerawanan bahaya longsor nilai
# 4,98 masuk pada tingkat kerawanan sedang 0,53 dan rendah 0,46.
#
# ### PEMBAHASAN
# Tampilan web yang digunakan untuk penentuan tingkat kerawanan longsor
# seperti yang terlihat pada gambar dibawah ini :
# Gambar 8. Interface penentuan tingkat kerawan longsor
# Gambar 9.

# %% [markdown]
# ![AI4.png](attachment:AI4.png)
# Gambar 8. Interface penentuan tingkat kerawan longsor

# %% [markdown]
# ![AI5.png](attachment:AI5.png)
# Gambar 9. titik koordinat 96°40'0"BT4°44'0"LU
#
# Pengukuran dilakukan dengan menggunakan analisa hasil pengolahan data
# yaitu dengan cara menggunakan metode Pretest dan Postest dengan
# membandingkan antara kenyataan pada data dengan hasil deteksi sistem
# yang mempunyai hasil sebagai berikut:
# Gambar 9. titik koordinat 96°40'0"BT4°44'0"LU
#
# Pengukuran dilakukan dengan menggunakan analisa hasil pengolahan data
# yaitu dengan cara menggunakan metode Pretest dan Postest dengan
# membandingkan antara kenyataan pada data dengan hasil deteksi sistem
# yang mempunyai hasil sebagai berikut:

# %% [markdown]
# ![AI6.png](attachment:AI6.png)

# %% [markdown]
# ![AI7.png](attachment:AI7.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## KESIMPULAN
# Sistem cerdas berbasis logika fuzzy dapat memudahkan pengguna
# untuk mengetahui tingkat kerawanan longsor pada daerah yang
# ditentukan. Sistem cerdas berbasis logika fuzzy mempunyai akurasi
# yang tinggi dalam menentukan daerah rawan longsor sehingga bisa
# dijadikan referensi untuk mengetahui tingkat kerawanan longsor pada
# daerah tertentu dan dapat dengan segera melakukan pencegahan atau
# upaya untuk menghindari terhadap terjadinya longsor.
#
# ## DAFTAR PUSTAKA
# Bagus Sulistiarto. & Cahyono, A.B. 2010. Studi tentang identifikasi longsor
# dengan menggunakan Citra Landsat dan Aster.
#
# Goupeng, Z. 2006. Data Analysis With Fuzzy Inference System. In
# Computational Intelligence: Method and Application. Singapore: School
# of Computer Engineering, Nanyang Technological University.
#
# Nandi. 2007. Longsor, FPIPS-UPI.
#
# Suyanto. 2008. Soft Computing Membangun Mesin Ber-IQ Tinggi. Bandung:
# Informatika.
#
# Sutojo, T., Mulyanto, Edy., & Suhartono, Vincent. 2011. Kecerdasan Buatan.
# Yogyakarta: Andi, 2011.
#
# Zadeh, L. A. 1994. Fuzzy Logic, Neural Networks and Soft Computing.
# Communication of The ACM , pp. 77-84
